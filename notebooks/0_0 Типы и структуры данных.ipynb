# %% [markdown]
# # **Типы данных и структуры данных в Python**

# %% [raw]
# Python предоставляет богатый набор встроенных типов данных и структур, которые можно разделить на 2 категории:
#
# ## **I. Базовые (примитивные) типы данных**
#
# ### 1. **Числовые типы**
# - `int` - целые числа (42, -10)
# - `float` - числа с плавающей точкой (3.14, -0.001)
# - `complex` - комплексные числа (3+4j)
# - `bool` - логический тип (наследник `int`: True=1, False=0)
#
# ```python
# num = 10          # int
# pi = 3.1415       # float
# comp = 2+3j       # complex
# flag = True       # bool
# ```
#
# ### 2. **Текстовый тип**
# - `str` - строки (последовательности Unicode)
#
# ```python
# text = "Hello"
# multiline = """Многострочная
# строка"""
# ```
#
# ### 3. **NoneType**
# - `None` - специальный тип для обозначения отсутствия значения
#
# ```python
# empty = None
# ```
#
# ## **II. Структуры данных (коллекции)**
#
# ### 1. **Последовательности (упорядоченные)**
# - `list` - изменяемый массив [1, 2, 3]
# - `tuple` - неизменяемый массив (1, 2, 3)
# - `range` - диапазон чисел range(5)
#
# ```python
# lst = [1, "two", 3.0]    # list
# tpl = (1, 2, 3)          # tuple
# rng = range(1, 10, 2)     # range
# ```
#
# ### 2. **Множества (неупорядоченные уникальные элементы)**
# - `set` - изменяемое множество {1, 2, 3}
# - `frozenset` - неизменяемое множество
#
# ```python
# st = {1, 2, 2, 3}        # {1, 2, 3} (дубли удаляются)
# f_st = frozenset(st)      # неизменяемый вариант
# ```
#
# ### 3. **Словари (пары ключ-значение)**
# - `dict` - изменяемый словарь {"key": "value"}
#
# ```python
# dct = {"name": "Alice", "age": 25}
# ```
#
# ### 4. **Байтовые типы**
# - `bytes` - неизменяемая байтовая строка b"hello"
# - `bytearray` - изменяемый массив байтов
# - `memoryview` - "вид" памяти для байтовых данных
#
# ```python
# bt = b"text"
# ba = bytearray(bt)
# mv = memoryview(ba)
# ```
#
# ## **III. Особенности типов Python**
#
# ### 1. **Динамическая типизация**
# ```python
# x = 10      # int
# x = "ten"   # теперь str
# ```
#
# ### 2. **Ссылочная модель**
# Все объекты передаются по ссылке (кроме примитивов)
#
# ### 3. **Проверка типов**
# ```python
# type(10)            # <class 'int'>
# isinstance(10, int) # True
# ```
#
# ## **IV. Иерархия типов**
#
# ```
# object
# ├── int
# ├── float
# ├── complex
# ├── bool
# ├── str
# ├── NoneType
# ├── list
# ├── tuple
# ├── range
# ├── set
# ├── frozenset
# ├── dict
# ├── bytes
# ├── bytearray
# └── memoryview
# ```
#
# ## **V. Когда что использовать?**
#
# | Структура | Изменяемость | Индексы   | Уникальность   | Когда использовать                       |
# |-----------|--------------|-----------|----------------|------------------------------------------|
# | `list`    | ✅ Да        | ✅ Да    | ❌ Нет         | Коллекции с возможностью изменения      |
# | `tuple`   | ❌ Нет       | ✅ Да    | ❌ Нет         | Неизменяемые последовательности         |
# | `set`     | ✅ Да        | ❌ Нет   | ✅ Да          | Уникальные элементы, проверка вхождения |
# | `dict`    | ✅ Да        | По ключу  | Ключи уникальны| Ассоциативные массивы                   |
# | `str`     | ❌ Нет       | ✅ Да    | ❌ Нет         | Текстовые данные                        |
#
# Python также позволяет создавать собственные типы данных через классы (ООП).

# %%
print(0)
# Out:
# 0
